# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.100885
# Nearest to is: traveler, demonym, hannibal, whole, dictator, indifference, quark, cement,
# Nearest to if: elohim, bowling, richness, waldseem, ornithologist, thirsty, written, neil,
# Nearest to many: bugle, accelerators, merodach, noc, foresaw, sedans, canarian, flights,
# Nearest to history: unleashed, excelled, peck, creativity, fairly, daisy, megaliths, parenthesis,
# Nearest to seven: bd, succeeds, attesting, krahn, solids, develops, jonathon, lhasa,
# Nearest to an: bro, improved, pandit, darmstadt, haut, overthrown, ckel, arnaud,
# Nearest to however: nil, make, cken, squeezing, sturgis, bacilli, fits, milliseconds,
# Nearest to new: weeks, present, cataclysmic, assisi, ruskin, miniszt, booklet, lexicography,
# Nearest to which: maharashtra, transmembrane, ordering, duff, chicks, ghq, ethnomusicology, cowdery,
# Nearest to and: splashdown, jess, formulate, kimmel, slip, kuan, pitch, nyc,
# Nearest to for: mq, patton, deploy, italiana, cyclone, byzantine, raza, bonfires,
# Nearest to who: clitoridectomy, forte, francisco, dalhousie, emotional, dup, figs, paddles,
# Nearest to such: overcast, magnetic, famagusta, stewards, refresh, vernet, childish, outkast,
# Nearest to this: olin, tia, ear, pyramids, poetess, ardent, inexperience, amphitryon,
# Nearest to d: maturing, explain, ahijah, jeremiah, teens, leetspeak, lsd, birmingham,
# Nearest to was: dit, abusers, fl, solon, spade, hoare, loops, further,
# Average loss at step 2000: 4.362740
# Average loss at step 4000: 3.861261
# Average loss at step 6000: 3.791129
# Average loss at step 8000: 3.687337
# Average loss at step 10000: 3.619141
# Nearest to is: was, are, has, be, originally, nigeria, brl, glaser,
# Nearest to if: kelley, elohim, bowling, what, neil, gadol, aedui, masculinity,
# Nearest to many: some, phoenix, paymaster, mancha, both, noc, most, these,
# Nearest to history: unleashed, reclassification, durch, scribes, peck, daisy, retells, limestone,
# Nearest to seven: eight, six, nine, three, four, five, zero, two,
# Nearest to an: piper, pardons, the, improved, excludes, lica, chick, hdz,
# Nearest to however: dialects, eid, language, nil, milliseconds, pious, vpn, absolute,
# Nearest to new: weeks, sustaining, booklet, justified, charlestown, lexicography, rtl, feminist,
# Nearest to which: that, this, who, also, it, what, there, although,
# Nearest to and: or, tubules, rejoined, in, who, american, canadian, margrethe,
# Nearest to for: in, comprehensible, of, cyclone, isaias, omniscience, droit, pygmies,
# Nearest to who: which, that, also, forte, often, terrains, he, and,
# Nearest to such: semifinals, cfr, stewards, designs, derision, gown, stamp, overcast,
# Nearest to this: it, the, which, a, his, that, allophone, vor,
# Nearest to d: explain, gehrig, b, pontchartrain, workprint, flavouring, ethical, debacle,
# Nearest to was: is, had, has, by, were, are, infecting, cochin,
# Average loss at step 12000: 3.607111
# Average loss at step 14000: 3.573127
# Average loss at step 16000: 3.403194
# Average loss at step 18000: 3.457655
# Average loss at step 20000: 3.542736
# Nearest to is: was, has, are, be, mullin, were, preterist, but,
# Nearest to if: elohim, kelley, aedui, contemporary, masculinity, defines, bowling, when,
# Nearest to many: some, several, all, these, other, most, paymaster, phoenix,
# Nearest to history: reclassification, solitary, rosalind, peck, unleashed, double, ina, embed,
# Nearest to seven: eight, six, four, five, nine, three, two, zero,
# Nearest to an: the, pardons, piper, excludes, improved, uncanny, mammalian, cooperating,
# Nearest to however: but, that, qualification, eid, vpn, milliseconds, dialects, surgically,
# Nearest to new: weeks, central, sustaining, justified, charlestown, present, rtl, bite,
# Nearest to which: that, this, who, also, it, what, there, but,
# Nearest to and: or, in, for, which, but, piacenza, at, publica,
# Nearest to for: and, of, almoravid, after, in, numerical, cyclone, misspelled,
# Nearest to who: he, which, they, also, often, eventually, she, terrains,
# Nearest to such: these, semifinals, well, cfr, other, designs, ganz, stewards,
# Nearest to this: it, which, the, its, he, that, his, kuro,
# Nearest to d: b, lomborg, gillespie, daro, stove, lune, fecture, suri,
# Nearest to was: is, has, were, had, be, been, became, does,
# Average loss at step 22000: 3.504252
# Average loss at step 24000: 3.490402
# Average loss at step 26000: 3.480775
# Average loss at step 28000: 3.480933
# Average loss at step 30000: 3.505430
# Nearest to is: was, has, are, be, became, consecrate, mullin, preterist,
# Nearest to if: when, kelley, elohim, defines, contemporary, aedui, engineered, is,
# Nearest to many: some, several, these, various, most, all, mma, ethology,
# Nearest to history: reclassification, ina, scribes, cyclic, marin, eldridge, rosalind, metadata,
# Nearest to seven: eight, nine, five, four, six, three, zero, two,
# Nearest to an: pardons, uncanny, piper, excludes, itself, amethyst, mammalian, breaking,
# Nearest to however: but, that, although, qualification, which, and, eid, milliseconds,
# Nearest to new: weeks, hgp, sustaining, justified, boudinot, viceroy, charlestown, flatly,
# Nearest to which: this, that, who, but, also, it, what, grau,
# Nearest to and: or, but, from, in, who, discord, including, of,
# Nearest to for: after, on, of, comprehensible, numerical, favoured, with, from,
# Nearest to who: he, they, which, env, she, also, terrains, eventually,
# Nearest to such: well, these, semifinals, cfr, known, other, many, skinny,
# Nearest to this: it, which, what, that, some, any, there, logistics,
# Nearest to d: b, lomborg, colombia, philosophic, daro, stove, gmt, gillespie,
# Nearest to was: is, had, has, were, been, became, by, unnecessarily,
# Average loss at step 32000: 3.505558
# Average loss at step 34000: 3.488502
# Average loss at step 36000: 3.461429
# Average loss at step 38000: 3.302666
# Average loss at step 40000: 3.432036
# Nearest to is: was, has, honestly, are, be, if, ramadan, mullin,
# Nearest to if: when, where, engineered, is, elohim, kelley, cannot, contemporary,
# Nearest to many: some, several, these, various, all, both, ethology, most,
# Nearest to history: ina, craft, reclassification, development, marin, scribes, lucrezia, administrator,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to an: pardons, uncanny, excludes, piper, lgbt, bud, pandit, permit,
# Nearest to however: but, that, although, which, though, it, ellensburg, nimitz,
# Nearest to new: weeks, virginals, penitentiary, satsuki, justified, cassette, central, baltimore,
# Nearest to which: that, this, also, who, what, it, but, usually,
# Nearest to and: or, but, spokane, while, in, tt, including, from,
# Nearest to for: in, rudy, retrieving, numerical, of, honestly, intercontinental, by,
# Nearest to who: he, which, often, she, also, env, they, terrains,
# Nearest to such: these, well, cfr, known, semifinals, constitutes, many, other,
# Nearest to this: which, it, the, that, ironworks, he, another, any,
# Nearest to d: b, lomborg, UNK, grays, gehrig, supine, gmt, shale,
# Nearest to was: is, has, became, were, had, been, be, playhouse,
# Average loss at step 42000: 3.432969
# Average loss at step 44000: 3.450671
# Average loss at step 46000: 3.447788
# Average loss at step 48000: 3.352270
# Average loss at step 50000: 3.378647
# Nearest to is: was, are, has, be, were, contains, mullin, while,
# Nearest to if: when, where, though, zacharias, ucd, cannot, crosstown, elohim,
# Nearest to many: some, several, various, these, both, most, rural, those,
# Nearest to history: ina, craft, multiplex, marin, lucrezia, development, administrator, hurdles,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to an: pardons, uncanny, pandit, another, excludes, piper, sinclair, mammalian,
# Nearest to however: but, although, while, though, that, when, eid, parodying,
# Nearest to new: central, awaken, fundamentalist, great, penitentiary, sustaining, coyote, boudinot,
# Nearest to which: that, this, also, what, who, usually, often, still,
# Nearest to and: or, while, but, of, including, fatah, in, like,
# Nearest to for: after, spacious, cyclone, while, numerical, conti, macmullen, rudy,
# Nearest to who: he, also, which, env, often, she, they, there,
# Nearest to such: well, these, cfr, known, many, semifinals, defined, constitutes,
# Nearest to this: which, it, another, some, that, he, nutty, the,
# Nearest to d: b, lomborg, grays, e, j, gehrig, profil, mamet,
# Nearest to was: is, has, had, were, became, by, be, been,
# Average loss at step 52000: 3.435783
# Average loss at step 54000: 3.424233
# Average loss at step 56000: 3.437545
# Average loss at step 58000: 3.395624
# Average loss at step 60000: 3.396830
# Nearest to is: was, are, has, preterist, be, seems, mullin, if,
# Nearest to if: when, where, though, cannot, since, although, whether, while,
# Nearest to many: some, several, various, these, both, most, such, all,
# Nearest to history: ina, list, cyclic, reclassification, development, scribes, landmines, economy,
# Nearest to seven: four, eight, six, nine, five, three, zero, two,
# Nearest to an: pardons, piper, another, doings, pandit, the, uncanny, cycorp,
# Nearest to however: but, although, though, while, since, that, when, this,
# Nearest to new: penitentiary, clyde, pc, understands, sevens, hallelujah, cassette, sustaining,
# Nearest to which: that, this, what, who, these, usually, it, there,
# Nearest to and: or, but, including, than, while, although, like, dairy,
# Nearest to for: after, rudy, without, of, or, musical, conti, almoravid,
# Nearest to who: he, env, which, often, also, she, really, eventually,
# Nearest to such: well, these, many, known, constitutes, semifinals, some, cfr,
# Nearest to this: it, which, that, there, the, some, nutty, mathematische,
# Nearest to d: b, r, grays, mamet, separable, j, gmt, lomborg,
# Nearest to was: is, became, were, had, has, be, playhouse, been,
# Average loss at step 62000: 3.236592
# Average loss at step 64000: 3.260839
# Average loss at step 66000: 3.403741
# Average loss at step 68000: 3.391181
# Average loss at step 70000: 3.364609
# Nearest to is: was, has, are, be, seems, makes, became, does,
# Nearest to if: when, though, where, while, whether, cannot, before, within,
# Nearest to many: some, several, various, these, all, most, both, few,
# Nearest to history: list, ina, development, period, framework, impression, landmines, reclassification,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to an: pardons, uncanny, cumann, unwitting, alger, the, sinclair, cycorp,
# Nearest to however: but, although, though, while, that, when, which, parodying,
# Nearest to new: penitentiary, endometrium, clyde, particular, hallelujah, cassette, sustaining, rich,
# Nearest to which: that, this, but, actually, also, what, and, still,
# Nearest to and: or, but, which, while, including, discord, than, of,
# Nearest to for: after, in, without, cyclone, numerical, firmer, curious, lent,
# Nearest to who: env, he, never, she, really, bogomils, often, they,
# Nearest to such: these, well, known, regarded, many, viewed, other, interpreted,
# Nearest to this: it, which, the, another, that, some, there, olin,
# Nearest to d: b, h, gillespie, lomborg, sa, gmt, waals, r,
# Nearest to was: is, has, were, had, became, been, be, gurmukhi,
# Average loss at step 72000: 3.369555
# Average loss at step 74000: 3.344960
# Average loss at step 76000: 3.315267
# Average loss at step 78000: 3.346105
# Average loss at step 80000: 3.376335
# Nearest to is: was, has, are, becomes, became, were, be, although,
# Nearest to if: when, where, though, cannot, since, whether, before, crosstown,
# Nearest to many: some, several, various, these, both, all, most, few,
# Nearest to history: list, nina, po, multiplex, waylon, emmanuel, ina, period,
# Nearest to seven: six, five, four, eight, nine, three, zero, two,
# Nearest to an: pardons, uncanny, ridicule, detects, sinclair, cumann, overflowing, shook,
# Nearest to however: although, but, though, that, while, misguided, when, cases,
# Nearest to new: endometrium, gos, pc, cassette, penitentiary, fundamentalist, dundee, rebel,
# Nearest to which: that, this, also, actually, usually, who, what, tp,
# Nearest to and: or, but, while, medici, including, kabir, walnut, discord,
# Nearest to for: after, firmer, fossil, tierney, interactivity, while, pygmies, cyclone,
# Nearest to who: he, never, she, often, which, env, really, actually,
# Nearest to such: these, well, known, many, certain, regarded, constitutes, defined,
# Nearest to this: which, it, the, another, that, itself, there, nutty,
# Nearest to d: b, m, p, f, h, n, lomborg, greg,
# Nearest to was: is, were, became, had, has, been, be, when,
# Average loss at step 82000: 3.411327
# Average loss at step 84000: 3.410264
# Average loss at step 86000: 3.389848
# Average loss at step 88000: 3.352226
# Average loss at step 90000: 3.363299
# Nearest to is: was, are, has, becomes, contains, be, involves, were,
# Nearest to if: when, where, though, since, before, unless, after, whether,
# Nearest to many: some, several, various, these, all, most, both, few,
# Nearest to history: list, multiplex, po, nina, emmanuel, ina, waylon, period,
# Nearest to seven: eight, four, five, six, nine, three, zero, one,
# Nearest to an: pardons, uncanny, sinclair, another, pandit, piper, unwitting, excludes,
# Nearest to however: but, although, though, that, cases, hyksos, kimmei, while,
# Nearest to new: endometrium, particular, zebrafish, gos, rich, specific, jaina, uncertainty,
# Nearest to which: that, this, also, what, actually, but, who, usually,
# Nearest to and: or, but, while, jimi, lemma, beatty, discord, deakin,
# Nearest to for: after, of, while, without, during, including, glorious, although,
# Nearest to who: he, often, never, already, which, actually, really, she,
# Nearest to such: well, known, these, certain, regarded, many, cfr, interpreted,
# Nearest to this: which, it, another, some, similar, the, cse, nutty,
# Nearest to d: b, lomborg, h, waals, sa, il, usd, mamet,
# Nearest to was: is, had, became, were, has, been, be, playhouse,
# Average loss at step 92000: 3.396681
# Average loss at step 94000: 3.252033
# Average loss at step 96000: 3.358310
# Average loss at step 98000: 3.240341
# Average loss at step 100000: 3.359888
# Nearest to is: was, has, became, be, are, seems, contains, had,
# Nearest to if: when, though, where, before, notoc, while, unless, because,
# Nearest to many: several, some, various, these, all, few, those, such,
# Nearest to history: list, emmanuel, framework, waylon, multiplex, imperfection, ina, science,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to an: pardons, cycorp, another, uncanny, piper, cumann, mammalian, ridicule,
# Nearest to however: but, although, that, especially, though, while, and, where,
# Nearest to new: endometrium, specific, different, penitentiary, cassette, gos, hallelujah, virginals,
# Nearest to which: that, this, actually, what, usually, but, also, who,
# Nearest to and: or, but, while, however, when, harpist, including, grau,
# Nearest to for: after, when, conti, without, spacious, although, while, if,
# Nearest to who: never, he, actually, she, often, which, already, ever,
# Nearest to such: well, known, these, many, certain, follows, regarded, mea,
# Nearest to this: which, it, another, he, cse, doug, legume, grau,
# Nearest to d: b, sa, c, escorts, greg, r, flavouring, k,
# Nearest to was: is, became, has, had, were, been, playhouse, while,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
from itertools import compress

data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    mask = [1] * span
    mask[skip_window] = 0
    batch[i, :] = list(compress(buffer, mask))
    labels[i, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train CBOW model

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
        embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# copied without chenges from above
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.606580
# Nearest to would: mileva, uke, actually, husband, sermons, tagalog, masonic, gol,
# Nearest to system: spook, paracompact, hays, denominated, markus, envelopes, abb, bokken,
# Nearest to time: styling, gabaa, eventually, amygdalin, bert, tw, csicop, hksar,
# Nearest to have: grenadines, pusc, freer, tyne, wafers, lazar, hyi, surpasses,
# Nearest to so: santorum, fatimid, hilaire, marcello, coding, cambodians, chat, ovens,
# Nearest to be: intended, moorehead, comparing, luxurious, schr, saviola, grimm, pleaded,
# Nearest to can: rewritable, redefined, jeffries, purposely, copley, nude, bridgewater, hardly,
# Nearest to many: sagittarius, inscription, tolvaj, distracting, pairwise, fleas, pristine, nylon,
# Nearest to his: starboard, pedersen, vor, altogether, inn, historic, moroni, gaps,
# Nearest to from: brava, thalamus, vogt, thurgood, leibniz, beside, fijian, multipoint,
# Nearest to zero: she, guernica, sisters, fv, establishment, russell, enclosed, needham,
# Nearest to or: counsellors, vdash, synge, taping, bates, friesland, bassoon, resignations,
# Nearest to five: skilling, paxton, independence, enormously, driscoll, gestis, transit, illuminating,
# Nearest to new: whitish, hedonist, trio, nonconfirmative, tunneling, cdb, soaked, morbid,
# Nearest to three: arukh, forthcoming, repetition, leno, scientist, ezquerra, fraktion, varsity,
# Nearest to d: deciphering, lol, susannah, goal, lipi, bracelet, pieces, musicians,
# Average loss at step 2000: 4.104762
# Average loss at step 4000: 3.562496
# Average loss at step 6000: 3.395938
# Average loss at step 8000: 3.249933
# Average loss at step 10000: 3.174446
# Nearest to would: can, will, could, may, might, should, must, to,
# Nearest to system: comparing, envelopes, encouragement, spreadsheets, bokken, abb, condita, resistance,
# Nearest to time: cde, limbs, duplicates, remus, julio, configurations, bankers, styling,
# Nearest to have: had, has, be, are, were, indelible, humour, grenadines,
# Nearest to so: santorum, successive, hilaire, fatimid, ovens, lockyer, zemin, schawlow,
# Nearest to be: refer, have, fanfare, been, were, skates, adf, dorian,
# Nearest to can: would, may, could, must, will, cannot, should, locksmithing,
# Nearest to many: some, several, all, cid, pairwise, various, other, slid,
# Nearest to his: their, her, its, the, brunner, inoculation, this, trapping,
# Nearest to from: into, in, rh, prokaryotes, between, schisms, thurgood, mls,
# Nearest to zero: four, eight, six, three, five, nine, seven, two,
# Nearest to or: and, than, jamiroquai, gives, punjab, scrolling, reverend, itasca,
# Nearest to five: six, eight, four, seven, nine, three, two, zero,
# Nearest to new: hedonist, nonconfirmative, coercive, initiatives, picts, countermeasures, congresses, malevolent,
# Nearest to three: four, six, seven, two, eight, five, zero, nine,
# Nearest to d: b, susannah, purana, hypothesized, deciphering, snoopy, fiftieth, dabbled,
# Average loss at step 12000: 3.204533
# Average loss at step 14000: 3.152760
# Average loss at step 16000: 3.183252
# Average loss at step 18000: 3.123545
# Average loss at step 20000: 2.987411
# Nearest to would: will, can, could, may, must, should, might, cannot,
# Nearest to system: systems, kamikaze, spreadsheets, problem, midnight, provisioning, kwame, condita,
# Nearest to time: period, julio, place, limbs, disproved, year, way, kanagawa,
# Nearest to have: had, has, were, be, are, refer, affiliate, provide,
# Nearest to so: successive, santorum, hilaire, fatimid, trivia, micronation, lockyer, afield,
# Nearest to be: have, been, is, refer, provide, were, become, are,
# Nearest to can: will, could, may, would, must, cannot, should, might,
# Nearest to many: some, several, various, these, all, those, such, most,
# Nearest to his: her, their, its, my, the, s, our, marijuana,
# Nearest to from: into, through, lookahead, thurgood, progressively, rh, beside, hell,
# Nearest to zero: seven, five, six, eight, four, three, nine, x,
# Nearest to or: and, than, jousting, itasca, pennies, novelette, though, crucifix,
# Nearest to five: six, eight, four, seven, three, zero, nine, two,
# Nearest to new: hedonist, thalberg, nonconfirmative, coercive, initiatives, controversies, record, hispanics,
# Nearest to three: four, eight, six, seven, five, two, zero, nine,
# Nearest to d: b, deciphering, purana, susannah, hypothesized, h, eton, avid,
# Average loss at step 22000: 3.080336
# Average loss at step 24000: 3.038967
# Average loss at step 26000: 3.005326
# Average loss at step 28000: 3.029933
# Average loss at step 30000: 3.006392
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to system: systems, problem, technology, calderas, procedure, bokken, kamikaze, polymath,
# Nearest to time: period, case, vassalage, arrival, mudd, julio, kanagawa, way,
# Nearest to have: had, has, were, are, refer, having, according, provide,
# Nearest to so: hashing, afield, too, santorum, pauses, pasted, dues, thyestes,
# Nearest to be: been, refer, become, being, is, incunabula, were, have,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to many: some, several, various, these, both, those, numerous, such,
# Nearest to his: her, their, its, my, whose, our, inoculation, nac,
# Nearest to from: into, through, under, between, before, rh, in, beside,
# Nearest to zero: seven, five, four, nine, eight, six, three, lb,
# Nearest to or: and, than, but, itasca, lob, jousting, macao, overflow,
# Nearest to five: six, four, seven, three, eight, nine, zero, two,
# Nearest to new: nonconfirmative, hedonist, congresses, initiatives, malevolent, thalberg, fifth, coercive,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to d: b, h, deciphering, purana, li, susannah, descriptors, dabbled,
# Average loss at step 32000: 2.830196
# Average loss at step 34000: 2.959061
# Average loss at step 36000: 2.945384
# Average loss at step 38000: 2.937129
# Average loss at step 40000: 2.930874
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to system: systems, problem, depriving, polymath, comparing, technology, midnight, charley,
# Nearest to time: period, result, vassalage, year, place, kanagawa, rule, guelleh,
# Nearest to have: had, has, were, are, be, refer, having, provide,
# Nearest to so: too, hashing, afield, lockyer, if, dues, maritimes, oxygenated,
# Nearest to be: been, have, become, being, refer, were, is, was,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to many: some, several, various, numerous, these, most, those, both,
# Nearest to his: her, their, its, my, our, your, kirkwood, mitral,
# Nearest to from: through, into, during, after, under, within, beside, with,
# Nearest to zero: seven, five, eight, six, nine, three, four, two,
# Nearest to or: and, while, than, but, jousting, overflow, reverend, fantastical,
# Nearest to five: six, four, seven, eight, three, nine, two, zero,
# Nearest to new: nonconfirmative, fifth, malevolent, hispanics, rhodes, owes, pathfinder, london,
# Nearest to three: five, six, four, two, eight, seven, nine, zero,
# Nearest to d: b, h, purana, deciphering, pseudonyms, hypothesized, zum, susannah,
# Average loss at step 42000: 2.956617
# Average loss at step 44000: 2.958020
# Average loss at step 46000: 2.905143
# Average loss at step 48000: 2.869818
# Average loss at step 50000: 2.849800
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to system: systems, problem, technology, provisioning, depriving, calderas, charley, function,
# Nearest to time: vassalage, period, year, result, term, place, julio, guelleh,
# Nearest to have: had, has, are, were, be, provide, include, having,
# Nearest to so: too, lockyer, then, exec, if, say, disloyal, later,
# Nearest to be: been, have, refer, become, being, adf, are, is,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to many: several, some, various, these, numerous, all, most, few,
# Nearest to his: her, their, its, my, our, your, the, personal,
# Nearest to from: into, during, through, in, within, before, beside, under,
# Nearest to zero: seven, eight, four, five, nine, six, three, two,
# Nearest to or: and, than, jousting, ornamented, anders, but, overflow, aggravated,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to new: fifth, old, owes, nonconfirmative, hedonist, initiatives, malevolent, pathfinder,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to d: b, deciphering, dabbled, avid, h, donald, continuations, lexis,
# Average loss at step 52000: 2.892050
# Average loss at step 54000: 2.861506
# Average loss at step 56000: 2.864212
# Average loss at step 58000: 2.750992
# Average loss at step 60000: 2.828696
# Nearest to would: will, could, can, must, should, might, may, cannot,
# Nearest to system: systems, problem, technology, function, method, procedure, plane, provisioning,
# Nearest to time: period, vassalage, kind, year, way, result, day, week,
# Nearest to have: had, has, having, were, be, provide, are, according,
# Nearest to so: too, pauses, exec, hashing, dues, forbids, lockyer, sometimes,
# Nearest to be: been, become, have, refer, being, provide, incunabula, is,
# Nearest to can: must, may, could, will, should, would, might, cannot,
# Nearest to many: several, some, various, numerous, these, those, few, all,
# Nearest to his: her, their, my, its, our, your, whose, the,
# Nearest to from: through, into, during, in, rh, lookahead, within, between,
# Nearest to zero: five, seven, six, eight, four, nine, three, x,
# Nearest to or: and, than, though, irv, anatole, while, convertible, herm,
# Nearest to five: seven, six, four, eight, nine, three, zero, two,
# Nearest to new: fifth, nonconfirmative, progressing, fourth, owes, maury, pinned, pluralist,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to d: b, h, traction, fiftieth, hypothesized, dabbled, n, susannah,
# Average loss at step 62000: 2.835813
# Average loss at step 64000: 2.771666
# Average loss at step 66000: 2.758859
# Average loss at step 68000: 2.713764
# Average loss at step 70000: 2.786010
# Nearest to would: could, will, might, must, should, can, may, cannot,
# Nearest to system: systems, technology, function, device, condita, problem, spreadsheets, branch,
# Nearest to time: period, vassalage, kind, week, demoralized, day, biplanes, guelleh,
# Nearest to have: had, has, include, having, suggest, were, are, contain,
# Nearest to so: too, sometimes, enough, pauses, very, lockyer, pitot, exec,
# Nearest to be: been, become, have, refer, being, is, denote, seem,
# Nearest to can: could, will, must, may, might, should, would, cannot,
# Nearest to many: some, several, various, numerous, these, those, all, most,
# Nearest to his: her, their, its, my, our, the, whose, your,
# Nearest to from: into, through, beside, during, under, before, schistosomiasis, after,
# Nearest to zero: five, six, eight, seven, four, nine, three, two,
# Nearest to or: and, than, unital, while, aggravated, anatole, vs, distinctively,
# Nearest to five: six, seven, eight, three, four, nine, zero, two,
# Nearest to new: fifth, nonconfirmative, fourth, polynesian, owes, different, partisans, minimization,
# Nearest to three: five, seven, four, eight, two, six, nine, zero,
# Nearest to d: b, traction, wedlock, dabbled, du, purana, te, h,
# Average loss at step 72000: 2.798887
# Average loss at step 74000: 2.645580
# Average loss at step 76000: 2.807905
# Average loss at step 78000: 2.824844
# Average loss at step 80000: 2.776945
# Nearest to would: could, will, must, should, might, can, may, cannot,
# Nearest to system: systems, technology, problem, codes, superstars, spreadsheets, nawaf, mummies,
# Nearest to time: period, kind, week, day, cases, biplanes, vassalage, way,
# Nearest to have: had, has, were, having, are, include, contain, provide,
# Nearest to so: too, very, afield, sometimes, lockyer, ventspils, pauses, feng,
# Nearest to be: become, been, refer, remain, form, denote, was, have,
# Nearest to can: could, may, must, will, should, might, would, cannot,
# Nearest to many: some, several, numerous, various, most, those, all, few,
# Nearest to his: her, their, my, your, its, whose, our, the,
# Nearest to from: into, through, during, beside, in, across, within, including,
# Nearest to zero: six, five, eight, seven, four, nine, three, two,
# Nearest to or: and, though, than, ornamented, jousting, although, metz, while,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to new: nonconfirmative, initiatives, separate, fifth, owes, admirals, recurrent, beginning,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to d: b, dabbled, sunglasses, carlo, fiftieth, te, continuations, wedlock,
# Average loss at step 82000: 2.668744
# Average loss at step 84000: 2.769876
# Average loss at step 86000: 2.733423
# Average loss at step 88000: 2.752608
# Average loss at step 90000: 2.739009
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to system: systems, superstars, procedure, problem, technology, mummies, codes, method,
# Nearest to time: period, kind, vassalage, week, year, waldeck, cases, demoralized,
# Nearest to have: had, has, were, include, are, contain, having, require,
# Nearest to so: too, sometimes, afield, pauses, falconer, very, trivia, hashing,
# Nearest to be: become, been, being, have, refer, get, cause, remain,
# Nearest to can: could, should, must, will, would, may, might, cannot,
# Nearest to many: some, several, numerous, various, most, few, both, all,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to from: through, into, during, including, across, magdalen, via, under,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to or: and, than, though, although, plus, ornamented, while, reconciling,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to new: nonconfirmative, fifth, separate, london, initiatives, polynesian, previous, veteran,
# Nearest to three: four, six, five, eight, two, seven, nine, zero,
# Nearest to d: b, te, continuations, fiftieth, purana, dabbled, sunglasses, parkinson,
# Average loss at step 92000: 2.675049
# Average loss at step 94000: 2.730691
# Average loss at step 96000: 2.704653
# Average loss at step 98000: 2.366681
# Average loss at step 100000: 2.403350
# Nearest to would: will, could, might, should, can, must, may, cannot,
# Nearest to system: systems, superstars, technology, method, procedure, problem, process, provisioning,
# Nearest to time: period, kind, vassalage, week, day, vowels, demoralized, waldeck,
# Nearest to have: had, has, include, are, were, having, contain, represent,
# Nearest to so: too, very, falconer, sometimes, pauses, spent, afield, dues,
# Nearest to be: become, been, have, being, refer, remain, get, produce,
# Nearest to can: could, cannot, should, must, will, might, would, may,
# Nearest to many: several, some, numerous, various, few, multiple, these, certain,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to from: through, via, across, including, into, before, beside, after,
# Nearest to zero: five, six, seven, four, eight, three, nine, two,
# Nearest to or: and, though, than, ornamented, but, itasca, subcode, gush,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to new: fifth, fourth, owes, previous, nonconfirmative, recurrent, london, initiatives,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to d: b, dabbled, insulating, continuations, diz, te, wedlock, typologically,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
